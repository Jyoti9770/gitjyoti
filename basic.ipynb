# %%
print("hello")
# Out:
# hello

# %%
name=input("enter your name")
age=int(input("enter your age"))
h=float(input("enter your height"))
print("my name is",name,"my age is",age,"and my height is",h)
# Out:
# my name is jyoti my age is 18 and my height is 4.11

# %%
l=int (input("enter length"))
w=int (input("enter width"))
area= l*w
print("Area is:",area)
# Out:
# Area is: 20

# %%
p=int(input("enter the principle amount"))
r=int(input("enter the rate"))
t=int(input("enter the time"))
SI=(p*r*t)/100
print("the simple interest is:",SI)
# Out:
# the simple interest is: 20.0

# %%
a=int(input("enter a value"))
if a%2==0:
    print("even number",a)
# Out:
# even number 4

# %%
a=int(input("enter a number"))
if a%2==0:
    print("even number",a)
else:
    print("odd number",a)
# Out:
# even number 6

# %%
per=int(input("enter a value: "))
if per>=60:
    print("1st div")
elif per>=48:
    print("2nd div")
elif per>=35:
    print("3rd div")
else:
    print("faill")
# Out:
# 3rd div

# %%
age=int(input("enter the age"))
if age>18:
    print("you can vote")
else:
    print("you can't vote")
# Out:
# you can vote

# %%
year=int(input("enter the year"))
if year%4==0 or year%100!=0:
    print("it is a leap year")
else:
    print("it is not a leap year")
# Out:
# it is a leap year

# %%
unit=int(input("enter the unit"))
if unit<=50:
       cost= unit*0.5
elif unit<200:
       cost=50*0.5+(unit-50)*0.75 
elif unit<=450:
       cost=50*0.5+150*0.75+(unit-200)*1.20
else:
       cost=50*0.5+150*0.75+250*1.20+(unit-450)*1.50
       final_amt=cost+cost*0.20
       print("final amount is",final_amt)

# %%
x=5
y=7
z=5
print(id(x),id(y),id(z))
y=9
print(id(x),id(y),id(z))
# Out:
# 140727790105640 140727790105704 140727790105640
# 140727790105640 140727790105768 140727790105640

# %%
l=int (input("enter the length"))
w=int (input("enter the width"))
area=l*w
print("area is:",area)
# Out:
# area is: 40

# %%
c=int (input(" celcius"))
f=(c*9.5)+32
print("correspoding f value is",f)
# Out:
# correspoding f value is 336.0

# %%
r=int(input("enter the radius"))
pi=3.14
area=pi*r*r
c=2*pi*r
print("area is :",area, "circumference is:",c)
# Out:
# area is : 153.86 circumference is: 43.96

# %%
age=int (input("enter the age"))
if age>18:
    print("you can vote")
else:
    print("you can't vote")
# Out:
# you can vote

# %%
age=int (input("enter the age"))
if age<=12:
    print("child")
elif age<=19:
    print("teenager")
elif age<=30:
    print("adult")
else :
    print("senior")
# Out:
# senior

# %%
a=int (input("enter the num"))
b=int (input("enter the num"))
c=int (input("enter the num"))
if a>b and a>c:
    print("a is largest",a)
elif b>c and b>a:
    print("b is largest",b)
else:
    print("c is largest",c)
# Out:
# c is largest 100

# %%
a=int (input("enter the side"))
b=int (input("enter the side"))
c=int (input("enter the side"))
if a==b and b==c:
    print("Triangle is equilateral")
elif a==b or a==c:
    print("Triangle is isosceles")
else:
    print("Triangle is scalene")
# Out:
# Triangle is scalene

# %%
unit=int (input(" enter the unit"))
if unit<=50:
    cost=unit*0.5
elif unit<=200:
    cost=50*0.5+(unit-50)*0.75
elif unit<=450:
    cost=50*0.5+150*0.75+(unit-200)*1.20
else:
    cost=50*0.5+150*0.75+250*1.20+(unit-450)*1.50
bill=cost+cost*0.20
print("final amount is :",bill)
# Out:
# final amount is : 120.0

# %%
distance=int(input("enter the distance"))
if distance<=10:
    bill=distance*11
elif distance<=100:
    bill=10*11+(distance-10)*10
else:
    bill=10*11+90*10+(distance-100)*9
    print("Total bill is:",bill)

# %%
for i in range(1,50):
    if i%3==0 and i%5==0 :
        print ("fizz buzz")
    elif i%5==0:
        print ("buzz")
    elif i%3==0:
        print ("fizz") 
    else :
        print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizz buzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizz buzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizz buzz
# 46
# 47
# fizz
# 49

# %%
n=int(input("enter a num"))
for i in range(1,n+1):
    if n%i==0:
        print(i)
# Out:
# 1
# 3
# 5

# %%
n=int (input("enter a num"))
even=0
odd=0
for i in range(1, n+1):
    if n%i==0 :
        if i%2==0:
          even=  even+1
        else:
           odd=odd+1
print("even factor is:", even, "odd factor is:", odd)
# Out:
# even factor is: 3 odd factor is: 1

# %%
n=int (input("enter a num"))
for i in range(2,n//2):
    if n%i!=0 :
       print ("it is a prime no") 
    else:
       print("it is not a prime no")
# Out:
# it is a prime no

# %%
n=int (input("enter a num"))
count=0
while n>0:
        n//=10
        count+=1
print("count is",count)
# Out:
# count is 4

# %%
n=int (input("enter a num"))
sum=0
while n>=1:
       rem=n%10
sum=sum+rem
print("sum of digit:", sum)

# %%
def factors(n):
    for i in range(1,n+1):
        if n%i==0:
            print(i,end=" ")
factors(12)
# Out:
# 1 2 3 4 6 12

# %%
def factorial(n):
    fact=1
    for i in range(1,n,i+1):
        fact=fact*i
    return fact 
n=int(input("enter a num"))

# %%
lst=[1,2,3,"hello",5,7]
print(lst)
for i in range(len(list)):
    print(lst[i],end=" ")
# Out:
# [1, 2, 3, 'hello', 5, 7]
# 1 2 3 hello 5 7

# %%
lst=[1,2,3,"hello",5,7]
lst1='hi'
for i in range(len(lst)):
    print(lst[i],end=" ")
# Out:
# 1 2 3 hello 5 7

# %%
lst=[3,5,7,8,12,10,2,5,8]
lst[-2::-5]
# Out:
# [5, 7]

# %%
lst=eval(input("enter the list"))
print(lst)
print(type(lst))

# %%
lst=[3,5,7,2,4,8]
for i in range(len(lst)):
    if lst[i]%2==0:
        lst[i]+=5
    else :
        lst[i]-=5
print(lst)
# Out:
# [-2, 0, 2, 7, 9, 13]

# %%
lst=[3,5,7,2,4,8]
for i in range(len(lst)):
    if lst[i]>lst[i]+1:
        print(lst[i])

# %%
lst=[7, -4, -2, 9, 0, 11, 17, 8, 19, 10]
lst.append("Hello")
lst.insert(-4,36)
lst1=[45,46,47]
lst.extend(lst1)
lst+=lst1 #extend
print(lst)
# Out:
# [7, -4, -2, 9, 0, 11, 17, 36, 8, 19, 10, 'Hello', 45, 46, 47, 45, 46, 47]

# %%
lst=[2,3,1,4,5,6,2,8]
lst_sum=0
for i in lst:
    lst_sum-i
    ans=[]
    for i in lst:
        ans.append(lst_sum-i)

print(ans)
print(lst)
# Out:
# [-2, -3, -1, -4, -5, -6, -2, -8]
# [2, 3, 1, 4, 5, 6, 2, 8]

# %%
lst=[[23,45,16],[45,3,12],[3,5,15]]
lst1=[]
for i in lst:
    lst1.append(i[0])
    lst1.append(i[-1])
print(lst1)
# Out:
# [23, 16, 45, 12, 3, 15]

# %%
lst=[i for i in range(4,26) if i%3==0 ]
print(lst)
# Out:
# [6, 9, 12, 15, 18, 21, 24]
